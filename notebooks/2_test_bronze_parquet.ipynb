# %%
import duckdb

duckdb.sql("""
    SELECT doi, title, publisher, published_date
    FROM '../data/bronze/bronze_crossref_works_20260616T175443Z_9774ad9f-e6fc-4fca-ad10-0ca914ad9c38.parquet'
    LIMIT 10
""").show()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import duckdb
#       2
# ----> 3 duckdb.sql("""
#       4     SELECT doi, title, publisher, published_date
#       5     FROM '../data/bronze/bronze_crossref_works_20260616T175443Z_9774ad9f-e6fc-4fca-ad10-0ca914ad9c38.parquet'
#       6     LIMIT 10
#
# IOException: IO Error: No files found that match the pattern "../data/bronze/bronze_crossref_works_20260616T175443Z_9774ad9f-e6fc-4fca-ad10-0ca914ad9c38.parquet"

# %%
duckdb.sql("""
    DESCRIBE SELECT doi, title, publisher, published_date
    FROM '../data/bronze/bronze_crossref_works_20260616T175443Z_9774ad9f-e6fc-4fca-ad10-0ca914ad9c38.parquet'
    LIMIT 10
""").show()
# Out:
# ┌────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │  column_name   │ column_type │  null   │   key   │ default │  extra  │
# │    varchar     │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ doi            │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ title          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ publisher      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ published_date │ DATE        │ YES     │ NULL    │ NULL    │ NULL    │
# └────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
import numpy as np
import pandas as pd

duckdb.sql("""
    SELECT *
    FROM '../data/bronze/bronze_crossref_works_20260616T175443Z_9774ad9f-e6fc-4fca-ad10-0ca914ad9c38.parquet'
    LIMIT 20
""").df()
# Out:
#                  doi                                              title  \
# 0   10.1157/13053457  Prevalencia del uso preconcepcional del ácido ...
# 1   10.1157/13053459  Mastopatía tras tratamiento con estradiol y pa...
# 2   10.1157/13053456                 Sonambulismo asociado con zolpidem
# 3   10.1157/13053452                             Respuesta de la autora
# 4   10.1157/13053449  Hepatitis C: diagnóstico y prevención desde la...
# 5   10.1157/13053460  Intoxicación por paracetamol líquidoen menores...
# 6   10.1157/13053448                           Respuesta de los autores
# 7   10.1157/13053451  Prevalencia de hepatitis A y hepatopatías crón...
# 8   10.1157/13053458  La espirometría en el diagnóstico de la enferm...
# 9   10.1157/13053723  Análisis de la demanda en los servicios de urg...
# 10  10.1157/13053468  Una apuesta por la calidad, la seriedad y la i...
# 11  10.1157/13053466  Comentario: Prevención de los factores de ries...
# ...

# %%
#duck db!

import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 200)

duckdb.sql("""
    SELECT doi, COUNT(DISTINCT record_hash)
    FROM '../data/bronze/bronze_crossref_works_20260616T215720Z_b4254f30-4316-4d24-b1d7-15850a048a68.parquet'
    GROUP BY doi
    HAVING COUNT(DISTINCT record_hash) > 1
""").df()
# Out:
# Empty DataFrame
# Columns: [doi, count(DISTINCT record_hash)]
# Index: []

# %%
duckdb.sql("""
    SELECT doi, COUNT(*) AS row_count
    FROM '../data/bronze/bronze_crossref_works_20260616T221037Z_4fabc488-1920-48db-84d7-fe736eceefa8.parquet'
    WHERE doi IS NOT NULL
    GROUP BY doi
    HAVING COUNT(*) > 1
""").df()
# Out:
# Empty DataFrame
# Columns: [doi, row_count]
# Index: []

# %%
#w/o duckdb!!!

import numpy as np
import pandas as pd
pd.set_option("display.max_rows", 10)

dd = duckdb.sql("""
    SELECT *
    FROM '../data/bronze/bronze_crossref_works_*.parquet'
""").df()

# %%
list(set(duckdb_list) - set(no_duckdb_list))
# Out:
# []

# %%
list(set(no_duckdb_list) - set(duckdb_list))
# Out:
# ['bronze_created_at_utc', 'raw_file', 'staged_at_utc', 'record_hash']

# %%
dd['alternative_ids_json'].to_list()
# Out:
# ['["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '["13002413"]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '["21902"]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
# ...
